# %%
#library import
import pandas as pd # for data manipulation and analysis
import numpy as np # for scientific computing with Python
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline
import seaborn as sns # for advanced visualization

# %%
df= pd.read_csv('../Data/Raw/Nepali_dataset.csv')

# %%
df_copy= df.copy()

# %%
# Importing custom python script to transform Hate sentiment dataset's Output classes to single target class
from create_target_label import create_target_column

df_copy,label_encoder = create_target_column(df_copy, "Sentiment", "Polarity")

# %%
list(label_encoder.classes_)
# Out:
# ['FEEDBACK_0',
#  'FEEDBACK_1',
#  'GENERAL_0',
#  'GENERAL_1',
#  'PROFANITY_0',
#  'PROFANITY_1',
#  'VIOLENCE_0',
#  'VIOLENCE_1']

# %%
df_copy.head()
# Out:
#                                                 Text           Aspect Term  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...        जोगाउन को लागि
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...             लखेटनु पछ
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !  ससकृती ध्वस्त पार्ने
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...              भुमाफिया
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...              बेची सके
#
#    Target
# 0       2
# 1       3
# 2       3
# 3       3
# 4       3

# %% [markdown]
# ## We created a single target for each Sentiment polarity to simplify Model training

# %%
# Dropping the Aspect Term feature

df_copy.drop("Aspect Term", axis=1, inplace= True)

# %% [markdown]
# ## Now we import a custom python script for returning the embeddings to the dataframe

# %% [markdown]
#  the models of encoders should be strictly defined as glove_model, word2vev_model, fasttext_model to work with the script

# %%
from generate_embeddings import load_word2vec_model, load_fasttext_model, load_glove_embeddings_dict, generate_glove_embeddings, generate_fasttext_embeddings, generate_word2vec_embeddings

# let's test on Glove
glove_model = load_glove_embeddings_dict("../Data/Preprocessed/glove_embeddings.txt")

# Generate GloVe embeddings
df_glove= df_copy.copy()
df_glove = generate_glove_embeddings(df_glove, "Text", glove_model)

# %%
df_glove.head()
# Out:
#                                                 Text  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...
#
#                                     glove_embeddings  Target
# 0  [-0.20295857, 0.3834819, 0.40714434, 0.2004464...       2
# 1  [-0.23167613, 0.38556933, 0.39157468, 0.078473...       3
# 2  [-0.22390805, 0.23769307, 0.42561498, 0.307606...       3
# 3  [-0.20357463, 0.2748196, 0.5259635, 0.24449758...       3
# 4  [-0.26102683, 0.37196454, 0.39651102, 0.138382...       3

# %%
glove_model["गुठी"]
# Out:
# array([-0.2505824 ,  0.18538585,  0.3547338 ,  0.14469296,  0.01504079,
#        -0.2619502 ,  0.12239891,  0.79824483, -0.21303594, -0.29311386,
#        -0.31846476, -0.3110927 , -0.0756995 ,  0.15410192, -0.006857  ,
#        -0.5565214 ,  0.11701115, -0.37545002, -0.03858599, -0.42105108,
#         0.20500495,  0.06896232,  0.43412763,  0.15874211, -0.1681155 ,
#        -0.09409916,  0.03480982,  0.01099336, -0.4772947 , -0.02961799,
#         0.21569028, -0.03261889, -0.1590511 , -0.564937  , -0.12503703,
#         0.23806275, -0.00435174, -0.2741125 , -0.22300099, -0.29128534,
#        -0.06358805, -0.19403796, -0.19090469,  0.07861757,  0.2571553 ,
#        -0.07051816, -0.24124868, -0.00766154,  0.18287888,  0.11368691,
#         0.19673643, -0.35600448,  0.23229878, -0.30381894, -0.08004031,
#         0.10745744, -0.01547284,  0.0074888 , -0.3179779 ,  0.07723755,
#         0.01180275,  0.02935823,  0.02466006,  0.0297574 , -0.36498818,
#         0.32565743,  0.13907443,  0.65415126, -0.40734887,  0.28883556,
#         0.2475525 ,  0.525335  ,  0.40486848, -0.10154314,  0.31647915,
#         0.13857888,  0.15776241, -0.17166165, -0.12711109, -0.19091414,
#        -0.29716125, -0.23629184, -0.37364876,  0.15896207, -0.24567121,
#        -0.5323823 ,  0.22777027,  0.33472085,  0.38019148,  0.00943383,
#         0.53050554, -0.0595666 ,  0.34827185,  0.03278639,  0.80197376,
#         0.21740967,  0.32196146, -0.2772198 ,  0.01105034, -0.10770611],
#       dtype=float32)

# %%
print(df_glove.loc[0,"glove_embeddings"])
# Out:
# [-0.20295857  0.3834819   0.40714434  0.20044647 -0.08248903 -0.31873846
#   0.03309819  1.0058982  -0.3017175  -0.2848489  -0.31270745 -0.38607934
#   0.04180235  0.3093452  -0.01735919 -0.59030586  0.21402082 -0.3227905
#   0.12231767 -0.6586451   0.19113716 -0.02794635  0.4365205   0.13144818
#  -0.2047246  -0.04487855  0.10453697  0.05309999 -0.54064023 -0.10749426
#   0.14293334 -0.07249115 -0.11021882 -0.5869757  -0.10406172  0.20567709
#   0.09961291 -0.5253951  -0.38013488 -0.3479512  -0.15888266 -0.24513465
#  -0.26896867  0.1284839   0.26869485 -0.14014159 -0.18190128 -0.08109819
#   0.07046348  0.11883952  0.16236936 -0.29878864  0.01655997 -0.28238165
#  -0.04316857  0.08078511  0.04420938 -0.07862841 -0.28732303  0.1141367
#   0.03066206  0.03885545 -0.20692438  0.09054345 -0.48928413  0.34497645
#   0.27996337  0.5911556  -0.45731106  0.4246466   0.13633202  0.6059423
#   0.43819064 -0.16285007  0.3649851   0.13866077  0.16921614 -0.21840213
#  -0.20323153 -0.23350824 -0.41941643 -0.29286063 -0.4376486   0.22524251
#  -0.30042425 -0.5802769   0.22230925  0.2847732   0.41099644 -0.03852952
#   0.41847122 -0.11434031  0.32082137  0.14820027  0.8620151   0.23786202
#   0.5376827  -0.2979662   0.24332212 -0.01529213]

# %%
# let's test on word2vec
word2vec_model = load_word2vec_model("../Data/Preprocessed/word2vec_embeddings.txt")

# Generate embeddings
df_word2vec= df_copy.copy()
df_word2vec = generate_word2vec_embeddings(df_word2vec, "Text", word2vec_model)

# %%
df_word2vec.head()
# Out:
#                                                 Text  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...
#
#                                  word2vec_embeddings  Target
# 0  [-0.24682237, 0.35339615, 0.3600155, 0.2801106...       2
# 1  [-0.24493806, 0.35242707, 0.3561586, 0.2733936...       3
# 2  [-0.27001628, 0.39004076, 0.39789718, 0.321739...       3
# 3  [-0.2993334, 0.428793, 0.44139257, 0.3441041, ...       3
# 4  [-0.22836164, 0.33540264, 0.33614093, 0.258507...       3

# %%
# let's test on word2vec
fasttext_model = load_fasttext_model("../Data/Preprocessed/fasttext_embeddings.model")

# Generate GloVe embeddings
df_fasttext= df_copy.copy()
df_fasttext = generate_fasttext_embeddings(df_fasttext, "Text", fasttext_model)

# %%
df_fasttext.head()
# Out:
#                                                 Text  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...
#
#                                  fasttext_embeddings  Target
# 0  [-0.28684744, -0.33160678, -0.7890507, -0.8186...       2
# 1  [-0.2671894, -0.30770808, -0.73609644, -0.7640...       3
# 2  [-0.29913396, -0.34533945, -0.8211022, -0.8495...       3
# 3  [-0.30930617, -0.35713866, -0.84729975, -0.877...       3
# 4  [-0.23962343, -0.27789554, -0.663212, -0.68909...       3

# %% [markdown]
# # now that we have encoded target and embeddings, let's train our classsifers

# %% [markdown]
# Classification Models
# 1. Support Vector Machines (SVC)
# 2. KNeighborsClassifer
# 3. GaussianNB
# 4. DecisionTreeCLassifer
# 5. LogisticRegression
# 6. RandomForestClassifer
# 7. xgboost

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, cohen_kappa_score
import matplotlib.pyplot as plt
import numpy as np

from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.multiclass import OneVsOneClassifier, OneVsRestClassifier

# %% [markdown]
# ## custom function for train_test_val split with random state 68

# %% [markdown]
# this function also flattens the embeddings so make sure df has only the embedding and target. <br>
# In future if new features are added modify the script to handle the changes !!

# %%
from train_test_val_split import train_test_val_split

# %%
df_fasttext.head()
# Out:
#                                                 Text  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...
#
#                                  fasttext_embeddings  Target
# 0  [-0.28684744, -0.33160678, -0.7890507, -0.8186...       2
# 1  [-0.2671894, -0.30770808, -0.73609644, -0.7640...       3
# 2  [-0.29913396, -0.34533945, -0.8211022, -0.8495...       3
# 3  [-0.30930617, -0.35713866, -0.84729975, -0.877...       3
# 4  [-0.23962343, -0.27789554, -0.663212, -0.68909...       3

# %%
df_fasttext.drop("Text", axis=1, inplace=True)

# Usage with fasttext:
X_train_fasttext, X_test_fasttext, X_val_fasttext, y_train_fasttext, y_test_fasttext, y_val_fasttext = train_test_val_split(df_fasttext, "fasttext_embeddings")
# Out:
# Shape of feature vectors (X): (4035, 100)
# Shape of target labels (y): (4035,)

# %%
X_train_fasttext.head()
# Out:
#             0         1         2         3         4         5         6   \
# 3216 -0.354994 -0.401457 -0.961021 -0.996064  0.349389  1.961095 -1.557485
# 2849 -0.245992 -0.282192 -0.673653 -0.698126  0.243795  1.374759 -1.090887
# 1476 -0.273750 -0.315074 -0.754889 -0.782559  0.270993  1.538326 -1.220775
# 1761 -0.236300 -0.272367 -0.648569 -0.672913  0.234735  1.324353 -1.050972
# 771  -0.261604 -0.299232 -0.715523 -0.742421  0.259249  1.463170 -1.159911
#
#             7         8         9   ...        90        91        92  \
# 3216  0.147942  0.035039 -0.690268  ... -0.914869 -0.246088  0.316536
# 2849  0.102428  0.027457 -0.483198  ... -0.644075 -0.174233  0.225753
# 1476  0.113274  0.029624 -0.539558  ... -0.723807 -0.194251  0.253595
# 1761  0.099124  0.026418 -0.464975  ... -0.622689 -0.168447  0.219184
# 771   0.108561  0.027901 -0.513164  ... -0.687228 -0.185059  0.242028
#
#             93        94        95        96        97        98        99
# 3216  0.305837  2.267665  0.854630  0.431082 -0.747942  1.043325 -1.124630
# 2849  0.214881  1.587696  0.600308  0.301314 -0.524042  0.731999 -0.788553
# 1476  0.240541  1.777570  0.674180  0.337078 -0.586460  0.818012 -0.884090
# 1761  0.206982  1.530638  0.580525  0.289594 -0.505590  0.705110 -0.759968
# 771   0.228669  1.689241  0.640355  0.319356 -0.558073  0.777817 -0.839772
#
# [5 rows x 100 columns]

# %%
y_train_fasttext.head()
# Out:
# 3216    4
# 2849    5
# 1476    3
# 1761    3
# 771     3
# Name: Target, dtype: int64

# %%
# similarly for word2vec and glove
df_word2vec.drop("Text", axis=1, inplace= True)

# %%
df_word2vec.head()
# Out:
#                                  word2vec_embeddings  Target
# 0  [-0.24682237, 0.35339615, 0.3600155, 0.2801106...       2
# 1  [-0.24493806, 0.35242707, 0.3561586, 0.2733936...       3
# 2  [-0.27001628, 0.39004076, 0.39789718, 0.321739...       3
# 3  [-0.2993334, 0.428793, 0.44139257, 0.3441041, ...       3
# 4  [-0.22836164, 0.33540264, 0.33614093, 0.258507...       3

# %%
X_train_word2vec, X_test_word2vec, X_val_word2vec, y_train_word2vec, y_test_word2vec, y_val_word2vec= train_test_val_split(df_word2vec,'word2vec_embeddings')
# Out:
# Shape of feature vectors (X): (4035, 100)
# Shape of target labels (y): (4035,)

# %%
df_glove.head()
# Out:
#                                                 Text  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...
#
#                                     glove_embeddings  Target
# 0  [-0.20295857, 0.3834819, 0.40714434, 0.2004464...       2
# 1  [-0.23167613, 0.38556933, 0.39157468, 0.078473...       3
# 2  [-0.22390805, 0.23769307, 0.42561498, 0.307606...       3
# 3  [-0.20357463, 0.2748196, 0.5259635, 0.24449758...       3
# 4  [-0.26102683, 0.37196454, 0.39651102, 0.138382...       3

# %%
df_glove.drop("Text", axis=1, inplace= True)


X_train_glove, X_test_glove, X_val_glove, y_train_glove, y_test_glove, y_val_glove= train_test_val_split(df_glove,"glove_embeddings")
# Out:
# Shape of feature vectors (X): (4035, 100)
# Shape of target labels (y): (4035,)

# %%
X_train_glove.head()
# Out:
#             0         1         2         3         4         5         6   \
# 3216 -0.678875  0.307790  0.626074  0.057378  0.002873 -0.464245  0.385003
# 2849 -0.327850  0.311719  0.410715  0.168037 -0.024735 -0.326920  0.106505
# 1476 -0.250571  0.576952  0.360461  0.166405 -0.222012 -0.523560  0.122009
# 1761 -0.268081  0.438185  0.482664  0.195184 -0.073386 -0.379066  0.101182
# 771  -0.254395  0.404727  0.415511  0.146633 -0.070628 -0.356741  0.130143
#
#             7         8         9   ...        90        91        92  \
# 3216  1.404212 -0.412796 -0.638118  ...  1.137787  0.107579  0.484039
# 2849  1.013709 -0.307274 -0.355287  ...  0.575423 -0.059387  0.384946
# 1476  1.073856 -0.484562 -0.285970  ...  0.524025 -0.118054  0.290951
# 1761  1.137148 -0.331812 -0.367749  ...  0.584401 -0.121861  0.401174
# 771   0.989381 -0.310936 -0.325312  ...  0.545256 -0.101969  0.335110
#
#             93        94        95        96        97        98        99
# 3216 -0.072771  1.477083  0.450302  0.621550 -0.620327  0.042195 -0.392253
# 2849  0.088724  0.995552  0.258379  0.502836 -0.352645  0.147830 -0.106012
# 1476  0.169504  0.890005  0.323574  0.660919 -0.144260  0.309374 -0.106221
# 1761  0.186643  1.021526  0.271901  0.602880 -0.292179  0.172051 -0.087624
# 771   0.149042  0.927584  0.250643  0.511927 -0.239838  0.161770 -0.130830
#
# [5 rows x 100 columns]

# %%
X_test_glove.head()
# Out:
#             0         1         2         3         4         5         6   \
# 2013 -0.123266  0.246226  0.363538  0.179543 -0.020093 -0.289064  0.058785
# 3393 -0.333951  0.437776  0.352264  0.284841 -0.069804 -0.483628 -0.014562
# 2495 -0.707721  0.411721  0.566869  0.013048 -0.080229 -0.517539  0.398803
# 801  -0.234041  0.290936  0.428837  0.096187 -0.017731 -0.171658  0.041271
# 3635 -0.242385  0.639476  0.261776  0.199216 -0.294976 -0.704818  0.188476
#
#             7         8         9   ...        90        91        92  \
# 2013  0.818213 -0.247715 -0.252605  ...  0.414768 -0.107486  0.329809
# 3393  1.130085 -0.386685 -0.293199  ...  0.551869 -0.077895  0.478092
# 2495  1.318809 -0.496150 -0.628745  ...  1.011994  0.052703  0.357971
# 801   0.877281 -0.117137 -0.287407  ...  0.492933 -0.068721  0.369964
# 3635  1.007023 -0.702517 -0.385062  ...  0.367197 -0.127801  0.138995
#
#             93        94        95        96        97        98        99
# 2013  0.092096  0.732383  0.212080  0.342444 -0.262249  0.112388 -0.076275
# 3393  0.047699  1.032319  0.380806  0.578642 -0.330099  0.103784  0.107367
# 2495 -0.040842  1.419699  0.401642  0.620424 -0.549168  0.195481 -0.381843
# 801   0.136167  0.852908  0.179147  0.527114 -0.264002  0.083539 -0.038433
# 3635  0.216276  0.759569  0.311518  0.624087 -0.115324  0.381468 -0.002564
#
# [5 rows x 100 columns]

# %%
y_test_glove.value_counts()
# Out:
# Target
# 3    178
# 2    105
# 0     43
# 4     30
# 7     17
# 6     11
# 5     11
# 1      8
# Name: count, dtype: int64

# %%
y_val_glove.value_counts()
# Out:
# Target
# 3    178
# 2    106
# 0     43
# 4     30
# 7     18
# 6     12
# 5     10
# 1      7
# Name: count, dtype: int64

# %%
# The classes and there mapping are

for class_name, encoded_value in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
    print(f"{class_name}: {encoded_value}")
# Out:
# FEEDBACK_0: 0
# FEEDBACK_1: 1
# GENERAL_0: 2
# GENERAL_1: 3
# PROFANITY_0: 4
# PROFANITY_1: 5
# VIOLENCE_0: 6
# VIOLENCE_1: 7

# %%
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, cohen_kappa_score
import matplotlib.pyplot as plt
from sklearn.multiclass import OneVsOneClassifier

def evaluate_multiclass_estimators(estimators, X_train, X_test, y_train, y_test):
    # Metrics lists
    metrics_dict = {
        "names": [],
        "accuracy_train": [],
        "accuracy_test": [],
        "auc_train": [],
        "auc_test": [],
        "precision_train": [],
        "precision_test": [],
        "recall_train": [],
        "recall_test": [],
        "f1_train": [],
        "f1_test": [],
        "kappa": [],
    }
    
    plt.figure(figsize=(12, 6))
    
    for name, classifier in estimators:
        print(f"Evaluating: {name}")
        metrics_dict["names"].append(name)
        
        if name=="RandomForest":
            model= classifier.fit(X_train, y_train)
        else:
            # Wrap classifier with OneVsOneClassifier if needed
            if hasattr(classifier, "predict_proba"):
                model = OneVsOneClassifier(classifier).fit(X_train, y_train)
            else:
                model = classifier.fit(X_train, y_train)
        
        
        # Predict
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)
        
        # Calculate metrics
        metrics_dict["accuracy_train"].append(accuracy_score(y_train, y_train_pred))
        metrics_dict["accuracy_test"].append(accuracy_score(y_test, y_test_pred))
        
        try:
            # Use predict_proba only if supported
            if hasattr(model, "predict_proba"):
                metrics_dict["auc_train"].append(roc_auc_score(y_train, model.predict_proba(X_train), multi_class="ovr", zero_division=0))
                metrics_dict["auc_test"].append(roc_auc_score(y_test, model.predict_proba(X_test), multi_class="ovr", zero_division=0))
            else:
                metrics_dict["auc_train"].append(None)
                metrics_dict["auc_test"].append(None)
        except Exception as e:
            metrics_dict["auc_train"].append(None)
            metrics_dict["auc_test"].append(None)
            print(f"Error calculating AUC for {name}: {e}")
        
        metrics_dict["precision_train"].append(precision_score(y_train, y_train_pred, average="macro", zero_division=0))
        metrics_dict["precision_test"].append(precision_score(y_test, y_test_pred, average="macro", zero_division=0))
        metrics_dict["recall_train"].append(recall_score(y_train, y_train_pred, average="macro", zero_division=0))
        metrics_dict["recall_test"].append(recall_score(y_test, y_test_pred, average="macro", zero_division=0))
        metrics_dict["f1_train"].append(f1_score(y_train, y_train_pred, average="macro"))
        metrics_dict["f1_test"].append(f1_score(y_test, y_test_pred, average="macro"))
        metrics_dict["kappa"].append(cohen_kappa_score(y_test, y_test_pred))
        
        # Confusion matrix
        conf_matrix = confusion_matrix(y_test, y_test_pred)
        print(f"Confusion Matrix for {name}:\n{conf_matrix}\n")
        
        # ROC Curve (if applicable)
        if hasattr(model, "predict_proba"):
            try:
                fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test), multi_class="ovr")
                plt.plot(fpr, tpr, label=f"{name} (AUC: {metrics_dict['auc_test'][-1]:.2f})")
            except ValueError as ve:
                print(f"{name} ROC curve failed: {ve}")
        else:
            print(f"{name} does not support predict_proba. Skipping ROC Curve.")

        # Print metrics
        print(f"Train Accuracy: {metrics_dict['accuracy_train'][-1]:.4f}")
        print(f"Test Accuracy: {metrics_dict['accuracy_test'][-1]:.4f}")
        print(f"Train Precision: {metrics_dict['precision_train'][-1]:.4f}")
        print(f"Test Precision: {metrics_dict['precision_test'][-1]:.4f}")
        print(f"Train Recall: {metrics_dict['recall_train'][-1]:.4f}")
        print(f"Test Recall: {metrics_dict['recall_test'][-1]:.4f}")
        print(f"Train F1: {metrics_dict['f1_train'][-1]:.4f}")
        print(f"Test F1: {metrics_dict['f1_test'][-1]:.4f}")
        print(f"Kappa Statistic: {metrics_dict['kappa'][-1]:.4f}\n")
    
    plt.plot([0, 1], [0, 1], "k--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

# %%
# Define base models and their multiclass wrappers
base_models = [
        ("SVC", OneVsOneClassifier(SVC(random_state=42, probability= True))),
        ("KNN", OneVsOneClassifier(KNeighborsClassifier())),
        ("GaussianNB", OneVsOneClassifier(GaussianNB())),
        ("DecisionTree", OneVsOneClassifier(DecisionTreeClassifier(random_state=42))),
        ("LogisticRegression", OneVsOneClassifier(LogisticRegression(max_iter=1000, random_state=42))),
        ("RandomForest", RandomForestClassifier(random_state=42))
    ]

# %%
evaluate_multiclass_estimators(base_models, X_train_word2vec, X_test_word2vec, y_train_word2vec, y_test_word2vec )
# Out:
# Evaluating: SVC
# Confusion Matrix for SVC:
# [[  0   0   0  43   0   0   0   0]
#  [  0   0   0   8   0   0   0   0]
#  [  0   0   0 105   0   0   0   0]
#  [  0   0   0 178   0   0   0   0]
#  [  0   0   0  30   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  17   0   0   0   0]]
#
# SVC does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.4414
# Test Accuracy: 0.4417
# Train Precision: 0.0552
# Test Precision: 0.0552
# Train Recall: 0.1250
# Test Recall: 0.1250
# Train F1: 0.0766
# Test F1: 0.0766
# Kappa Statistic: 0.0000
#
# Evaluating: KNN
# Confusion Matrix for KNN:
# [[  5   0  14  23   1   0   0   0]
#  [  0   0   2   6   0   0   0   0]
#  [ 11   0  43  51   0   0   0   0]
#  [  8   0  29 134   6   0   0   1]
#  [  0   0   1  25   3   1   0   0]
#  [  0   0   1   9   1   0   0   0]
#  [  0   0   2   9   0   0   0   0]
#  [  0   0   4  13   0   0   0   0]]
#
# KNN does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.5802
# Test Accuracy: 0.4591
# Train Precision: 0.4409
# Test Precision: 0.1782
# Train Recall: 0.2585
# Test Recall: 0.1723
# Train F1: 0.2775
# Test F1: 0.1652
# Kappa Statistic: 0.1460
#
# Evaluating: GaussianNB
# Confusion Matrix for GaussianNB:
# [[ 6  2  6  0  1 10  0 18]
#  [ 3  0  1  0  0  1  0  3]
#  [15  4 25  0  1 14  0 46]
#  [23  2 31  0 17 35  0 70]
#  [ 2  1  2  0  4  6  0 15]
#  [ 0  0  0  0  1  2  0  8]
#  [ 1  0  1  0  2  2  0  5]
#  [ 3  1  1  0  4  1  0  7]]
#
# GaussianNB does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.1276
# Test Accuracy: 0.1092
# Train Precision: 0.1559
# Test Precision: 0.0861
# Train Recall: 0.1613
# Test Recall: 0.1381
# Train F1: 0.0959
# Test F1: 0.0840
# Kappa Statistic: 0.0252
#
# Evaluating: DecisionTree
# Confusion Matrix for DecisionTree:
# [[  3   0  17  20   0   0   1   2]
#  [  2   0   1   3   1   0   0   1]
#  [  5   0  45  45   1   0   2   7]
#  [ 13   3  13 123  13   3   5   5]
#  [  1   0   1  17   5   3   2   1]
#  [  0   0   0   3   4   4   0   0]
#  [  0   0   4   5   0   0   0   2]
#  [  1   1   3   8   2   0   1   1]]
#
# DecisionTree does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.8680
# Test Accuracy: 0.4491
# Train Precision: 0.8648
# Test Precision: 0.2312
# Train Recall: 0.7522
# Test Recall: 0.2223
# Train F1: 0.7843
# Test F1: 0.2239
# Kappa Statistic: 0.1960
#
# Evaluating: LogisticRegression
# Confusion Matrix for LogisticRegression:
# [[  0   0   0  43   0   0   0   0]
#  [  0   0   0   8   0   0   0   0]
#  [  0   0   2 103   0   0   0   0]
#  [  0   0   0 178   0   0   0   0]
#  [  0   0   0  30   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  17   0   0   0   0]]
#
# LogisticRegression does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.4517
# Test Accuracy: 0.4467
# Train Precision: 0.1411
# Test Precision: 0.1805
# Train Recall: 0.1306
# Test Recall: 0.1274
# Train F1: 0.0894
# Test F1: 0.0815
# Kappa Statistic: 0.0105
#
# Evaluating: RandomForest
# Error calculating AUC for RandomForest: got an unexpected keyword argument 'zero_division'
# Confusion Matrix for RandomForest:
# [[  1   0  23  18   0   0   1   0]
#  [  1   0   1   4   1   0   0   1]
#  [  0   0  57  46   0   0   1   1]
#  [ 10   3  15 132  11   2   1   4]
#  [  1   0   0  19   5   3   2   0]
#  [  0   0   1   3   3   4   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   1   1  14   1   0   0   0]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 evaluate_multiclass_estimators(base_models, X_train_word2vec, X_test_word2vec, y_train_word2vec, y_test_word2vec )
#
# Cell In[37], line 74, in evaluate_multiclass_estimators(estimators, X_train, X_test, y_train, y_test)
#      72 if hasattr(model, "predict_proba"):
#      73     try:
# ---> 74         fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test), multi_class="ovr")
#      75         plt.plot(fpr, tpr, label=f"{name} (AUC: {metrics_dict['auc_test'][-1]:.2f})")
#      76     except ValueError as ve:
#
# File ~/myenv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File /usr/lib/python3.11/inspect.py:3212, in Signature.bind(self, *args, **kwargs)
#    3207 def bind(self, /, *args, **kwargs):
#    3208     """Get a BoundArguments object, that maps the passed `args`
#    3209     and `kwargs` to the function's signature.  Raises `TypeError`
#    3210     if the passed arguments can not be bound.
#    3211     """
# -> 3212     return self._bind(args, kwargs)
#
# File /usr/lib/python3.11/inspect.py:3201, in Signature._bind(self, args, kwargs, partial)
#    3199         arguments[kwargs_param.name] = kwargs
#    3200     else:
# -> 3201         raise TypeError(
#    3202             'got an unexpected keyword argument {arg!r}'.format(
#    3203                 arg=next(iter(kwargs))))
#    3205 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'multi_class'

# %%
evaluate_multiclass_estimators(base_models, X_train_fasttext, X_test_fasttext, y_train_fasttext, y_test_fasttext)
# Out:
# Evaluating: SVC
# Confusion Matrix for SVC:
# [[  0   0   0  43   0   0   0   0]
#  [  0   0   0   8   0   0   0   0]
#  [  0   0   0 105   0   0   0   0]
#  [  0   0   0 178   0   0   0   0]
#  [  0   0   0  30   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  17   0   0   0   0]]
#
# SVC does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.4414
# Test Accuracy: 0.4417
# Train Precision: 0.0552
# Test Precision: 0.0552
# Train Recall: 0.1250
# Test Recall: 0.1250
# Train F1: 0.0766
# Test F1: 0.0766
# Kappa Statistic: 0.0000
#
# Evaluating: KNN
# Confusion Matrix for KNN:
# [[  4   0  11  27   1   0   0   0]
#  [  0   0   1   7   0   0   0   0]
#  [ 11   0  28  65   0   1   0   0]
#  [  3   0  27 143   3   1   0   1]
#  [  0   0   1  26   3   0   0   0]
#  [  0   0   1  10   0   0   0   0]
#  [  1   0   2   7   0   0   0   1]
#  [  1   0   0  15   0   0   0   1]]
#
# KNN does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.5753
# Test Accuracy: 0.4442
# Train Precision: 0.3927
# Test Precision: 0.2291
# Train Recall: 0.2486
# Test Recall: 0.1652
# Train F1: 0.2638
# Test F1: 0.1632
# Kappa Statistic: 0.1010
#
# Evaluating: GaussianNB
# Confusion Matrix for GaussianNB:
# [[13  1  1  0  2  0  4 22]
#  [ 3  0  1  0  1  0  0  3]
#  [30  2  9  0  8  0 11 45]
#  [40  4 11  0 18  0 17 88]
#  [ 8  1  0  0  2  0  2 17]
#  [ 1  1  0  0  0  0  0  9]
#  [ 2  0  0  0  2  0  1  6]
#  [ 5  0  0  0  1  0  1 10]]
#
# GaussianNB does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.0892
# Test Accuracy: 0.0868
# Train Precision: 0.0780
# Test Precision: 0.0841
# Train Recall: 0.1435
# Test Recall: 0.1417
# Train F1: 0.0702
# Test F1: 0.0648
# Kappa Statistic: 0.0167
#
# Evaluating: DecisionTree
# Confusion Matrix for DecisionTree:
# [[  5   0  21  15   1   0   1   0]
#  [  1   0   1   4   1   0   0   1]
#  [  5   0  49  43   2   0   4   2]
#  [ 16   4  21 112  15   1   2   7]
#  [  2   0   1  14   8   2   2   1]
#  [  2   0   0   3   3   3   0   0]
#  [  0   0   1   8   1   0   1   0]
#  [  1   2   2   9   2   0   0   1]]
#
# DecisionTree does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.8680
# Test Accuracy: 0.4442
# Train Precision: 0.8648
# Test Precision: 0.2664
# Train Recall: 0.7522
# Test Recall: 0.2377
# Train F1: 0.7843
# Test F1: 0.2465
# Kappa Statistic: 0.1977
#
# Evaluating: LogisticRegression
# Confusion Matrix for LogisticRegression:
# [[  0   0   0  43   0   0   0   0]
#  [  0   0   0   8   0   0   0   0]
#  [  0   0   0 105   0   0   0   0]
#  [  0   0   0 178   0   0   0   0]
#  [  0   0   0  30   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   0  17   0   0   0   0]]
#
# LogisticRegression does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.4414
# Test Accuracy: 0.4417
# Train Precision: 0.0552
# Test Precision: 0.0552
# Train Recall: 0.1250
# Test Recall: 0.1250
# Train F1: 0.0766
# Test F1: 0.0766
# Kappa Statistic: 0.0000
#
# Evaluating: RandomForest
# Confusion Matrix for RandomForest:
# [[  2   0  23  17   0   0   1   0]
#  [  1   0   0   5   1   0   0   1]
#  [  2   0  45  56   0   0   1   1]
#  [ 10   2  16 132  10   2   1   5]
#  [  1   0   0  19   5   2   3   0]
#  [  0   0   1   4   3   3   0   0]
#  [  0   0   1   9   1   0   0   0]
#  [  1   1   2  10   1   0   1   1]]
#
# RandomForest does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.8680
# Test Accuracy: 0.4665
# Train Precision: 0.8579
# Test Precision: 0.2431
# Train Recall: 0.7309
# Test Recall: 0.2144
# Train F1: 0.7841
# Test F1: 0.2195
# Kappa Statistic: 0.1875
# /tmp/ipykernel_77972/3475569641.py:92: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
evaluate_multiclass_estimators(base_models, X_train_glove, X_test_glove, y_train_glove, y_test_glove )
# Out:
# Evaluating: SVC
# Confusion Matrix for SVC:
# [[  0   0  21  22   0   0   0   0]
#  [  0   0   2   6   0   0   0   0]
#  [  0   0  66  39   0   0   0   0]
#  [  0   0  17 161   0   0   0   0]
#  [  0   0   0  30   0   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   2   9   0   0   0   0]
#  [  0   0   2  15   0   0   0   0]]
#
# SVC does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.5821
# Test Accuracy: 0.5633
# Train Precision: 0.1531
# Test Precision: 0.1437
# Train Recall: 0.1992
# Test Recall: 0.1916
# Train F1: 0.1703
# Test F1: 0.1622
# Kappa Statistic: 0.2814
#
# Evaluating: KNN
# Confusion Matrix for KNN:
# [[  6   0  17  17   2   1   0   0]
#  [  0   0   2   5   1   0   0   0]
#  [  8   1  57  38   0   0   0   1]
#  [  6   1  21 134  12   1   1   2]
#  [  1   0   1  16  10   1   1   0]
#  [  1   0   1   6   3   0   0   0]
#  [  1   0   0  10   0   0   0   0]
#  [  1   1   3  11   1   0   0   0]]
#
# KNN does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.6323
# Test Accuracy: 0.5136
# Train Precision: 0.5445
# Test Precision: 0.2149
# Train Recall: 0.3107
# Test Recall: 0.2211
# Train F1: 0.3411
# Test F1: 0.2143
# Kappa Statistic: 0.2651
#
# Evaluating: GaussianNB
# Confusion Matrix for GaussianNB:
# [[15  2 12  1  2  0  5  6]
#  [ 3  0  1  0  0  4  0  0]
#  [28  3 46  3  0  5 10 10]
#  [14  8 14 12 33 46 31 20]
#  [ 0  0  0  0 13 12  2  3]
#  [ 0  0  0  1  0  6  2  2]
#  [ 2  0  0  2  0  2  4  1]
#  [ 3  1  0  2  4  1  4  2]]
#
# GaussianNB does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.2469
# Test Accuracy: 0.2432
# Train Precision: 0.2496
# Test Precision: 0.2345
# Train Recall: 0.2984
# Test Recall: 0.2893
# Train F1: 0.2046
# Test F1: 0.1940
# Kappa Statistic: 0.1483
#
# Evaluating: DecisionTree
# Confusion Matrix for DecisionTree:
# [[  6   1  17  17   0   0   1   1]
#  [  1   0   1   4   1   0   0   1]
#  [  6   1  55  35   2   0   3   3]
#  [ 16   3  18 109  18   3   3   8]
#  [  1   0   0  16   7   2   3   1]
#  [  0   0   0   5   3   3   0   0]
#  [  2   0   1   6   0   1   1   0]
#  [  1   1   2  11   1   0   0   1]]
#
# DecisionTree does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.8680
# Test Accuracy: 0.4516
# Train Precision: 0.8648
# Test Precision: 0.2517
# Train Recall: 0.7522
# Test Recall: 0.2414
# Train F1: 0.7843
# Test F1: 0.2453
# Kappa Statistic: 0.2153
#
# Evaluating: LogisticRegression
# Confusion Matrix for LogisticRegression:
# [[  2   0  19  21   1   0   0   0]
#  [  0   0   2   6   0   0   0   0]
#  [  1   0  69  35   0   0   0   0]
#  [  1   0  16 160   1   0   0   0]
#  [  0   0   0  25   5   0   0   0]
#  [  0   0   0  11   0   0   0   0]
#  [  0   0   2   9   0   0   0   0]
#  [  1   0   2  14   0   0   0   0]]
#
# LogisticRegression does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.5821
# Test Accuracy: 0.5856
# Train Precision: 0.2325
# Test Precision: 0.2889
# Train Recall: 0.2065
# Test Recall: 0.2211
# Train F1: 0.1854
# Test F1: 0.2116
# Kappa Statistic: 0.3298
#
# Evaluating: RandomForest
# Confusion Matrix for RandomForest:
# [[  5   0  24  12   1   0   1   0]
#  [  1   0   1   4   1   0   0   1]
#  [  0   0  70  33   0   0   1   1]
#  [ 10   2  13 135  11   1   1   5]
#  [  1   0   0  16   9   2   2   0]
#  [  0   0   0   5   3   3   0   0]
#  [  1   0   1   8   1   0   0   0]
#  [  0   1   2  11   2   0   0   1]]
#
# RandomForest does not support predict_proba. Skipping ROC Curve.
# Train Accuracy: 0.8680
# Test Accuracy: 0.5533
# Train Precision: 0.8670
# Test Precision: 0.3072
# Train Recall: 0.7278
# Test Recall: 0.2716
# Train F1: 0.7844
# Test F1: 0.2784
# Kappa Statistic: 0.3344
# /tmp/ipykernel_77972/3475569641.py:92: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
