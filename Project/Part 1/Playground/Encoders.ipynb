# %%
# Library import
import pandas as pd # for data manipulation and analysis
import numpy as np # for scientific computing with Python
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline
import seaborn as sns # for advanced visualization
import os

# %%
df= pd.read_csv('../Data/Raw/Nepali_dataset.csv')

# %%
df_copy= df.copy()
df_copy.head()
# Out:
#                                                 Text           Aspect Term  \
# 0  गुठी विधेक ल्याएर ठमेल मा राज गुठि को जग्गा मा...        जोगाउन को लागि
# 1  दले ले देश सकेछन सबै बेचे र खान सुरू गरेछन अब ...             लखेटनु पछ
# 2        नेपाल को ससकृती ध्वस्त पार्ने योजना हो यो !  ससकृती ध्वस्त पार्ने
# 3  मठ मन्दिर गुम्बा का जग्गा हरु मा भुमाफिया को न...              भुमाफिया
# 4  नेपाल का कल कर्खाना र नदि नाला बेची सके अब मठ ...              बेची सके
#
#   Sentiment  Polarity
# 0   GENERAL         0
# 1   GENERAL         1
# 2   GENERAL         1
# 3   GENERAL         1
# 4   GENERAL         1

# %%
# Import embedding Models
from gensim.models import Word2Vec, FastText, KeyedVectors

# %%
# Output path
output_path = "../Data/Embeddings/"

# %% [markdown]
# # FastText

# %%
def create_fasttext_embeddings(texts, output_file):
    sentences = [text.split() for text in texts]  # Tokenize each text into words
    fasttext_model = FastText(sentences, vector_size=100, window=5, min_count=1, workers=4)  # Train FastText model
    fasttext_model.save(output_file)  # Save the entire FastText model

# Specify the output file path
fasttext_output_file = os.path.join(output_path, 'fasttext_embeddings.model')

# Example call
create_fasttext_embeddings(df_copy['Text'], fasttext_output_file)
# Out:
# 2024-12-19 20:12:08,279 | INFO | gensim.models.word2vec | collecting all words and their counts
# 2024-12-19 20:12:08,280 | INFO | gensim.models.word2vec | PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-12-19 20:12:08,312 | INFO | gensim.models.word2vec | collected 9517 word types from a corpus of 72367 raw words and 4035 sentences
# 2024-12-19 20:12:08,314 | INFO | gensim.models.word2vec | Creating a fresh vocabulary
# 2024-12-19 20:12:08,347 | INFO | gensim.utils | FastText lifecycle event {'msg': 'effective_min_count=1 retains 9517 unique words (100.00% of original 9517, drops 0)', 'datetime': '2024-12-19T20:12:08.347765', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-19 20:12:08,348 | INFO | gensim.utils | FastText lifecycle event {'msg': 'effective_min_count=1 leaves 72367 word corpus (100.00% of original 72367, drops 0)', 'datetime': '2024-12-19T20:12:08.348676', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-19 20:12:08,398 | INFO | gensim.models.word2vec | deleting the raw counts dictionary of 9517 items
# 2024-12-19 20:12:08,399 | INFO | gensim.models.word2vec | sample=0.001 downsamples 41 most-common words
# 2024-12-19 20:12:08,399 | INFO | gensim.utils | FastText lifecycle event {'msg': 'downsampling leaves estimated 57113.86719634944 word corpus (78.9%% of prior 72367)', 'datetime': '2024-12-19T20:12:08.399903', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-19 20:12:08,515 | INFO | gensim.models.fasttext | estimated required memory for 9517 words, 2000000 buckets and 100 dimensions: 813932320 bytes
# 2024-12-19 20:12:08,516 | INFO | gensim.models.word2vec | resetting layer weights
# 2024-12-19 20:12:10,097 | INFO | gensim.utils | FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-12-19T20:12:10.097952', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'build_vocab'}
# 2024-12-19 20:12:10,098 | INFO | gensim.utils | FastText lifecycle event {'msg': 'training model with 4 workers on 9517 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-12-19T20:12:10.098928', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'train'}
# 2024-12-19 20:12:10,286 | INFO | gensim.models.word2vec | EPOCH 0: training on 72367 raw words (57128 effective words) took 0.2s, 319359 effective words/s
# 2024-12-19 20:12:10,465 | INFO | gensim.models.word2vec | EPOCH 1: training on 72367 raw words (57162 effective words) took 0.2s, 334266 effective words/s
# 2024-12-19 20:12:10,626 | INFO | gensim.models.word2vec | EPOCH 2: training on 72367 raw words (57097 effective words) took 0.2s, 364741 effective words/s
# 2024-12-19 20:12:10,791 | INFO | gensim.models.word2vec | EPOCH 3: training on 72367 raw words (57157 effective words) took 0.2s, 362243 effective words/s
# 2024-12-19 20:12:10,980 | INFO | gensim.models.word2vec | EPOCH 4: training on 72367 raw words (57226 effective words) took 0.2s, 311189 effective words/s
# 2024-12-19 20:12:10,981 | INFO | gensim.utils | FastText lifecycle event {'msg': 'training on 361835 raw words (285770 effective words) took 0.9s, 324042 effective words/s', 'datetime': '2024-12-19T20:12:10.981469', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'train'}
# 2024-12-19 20:12:11,266 | INFO | gensim.utils | FastText lifecycle event {'params': 'FastText<vocab=9517, vector_size=100, alpha=0.025>', 'datetime': '2024-12-19T20:12:11.266534', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'created'}
# 2024-12-19 20:12:11,267 | INFO | gensim.utils | FastText lifecycle event {'fname_or_handle': '../Data/Preprocessed/fasttext_embeddings.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-12-19T20:12:11.267226', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'saving'}
# 2024-12-19 20:12:11,267 | INFO | gensim.utils | storing np array 'vectors_ngrams' to ../Data/Preprocessed/fasttext_embeddings.model.wv.vectors_ngrams.npy
# 2024-12-19 20:12:12,822 | INFO | gensim.utils | not storing attribute buckets_word
# 2024-12-19 20:12:12,843 | INFO | gensim.utils | not storing attribute vectors
# 2024-12-19 20:12:12,844 | INFO | gensim.utils | not storing attribute cum_table
# 2024-12-19 20:12:13,240 | INFO | gensim.utils | saved ../Data/Preprocessed/fasttext_embeddings.model

# %% [markdown]
# # Word2Vec

# %%
def create_word2vec_embeddings(texts, output_file):
    sentences = [text.split() for text in texts]
    word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    word2vec_model.save(output_file)

word2vec_output_file = os.path.join(output_path, 'word2vec_embeddings.txt')
create_word2vec_embeddings(df_copy['Text'], word2vec_output_file)

# Load the model
model = Word2Vec.load('../Data/Embeddings/word2vec_embeddings.txt')

# Open the output file in write mode
output_file_path = '../Data/Embeddings/word2vec_embeddings.txt'
with open(output_file_path, 'w', encoding='utf-8') as f:
    # Writing metadata line
    f.write(f"9517 100\n")
    
    for word in model.wv.index_to_key:
        vector = model.wv[word]
        vector_str = ' '.join(f'{value:.6f}' for value in vector)
        f.write(f"{word} {vector_str}\n")

# %% [markdown]
# # Glove

# %%
def create_glove_embeddings(texts, output_file, dim=100, window=5, epochs=15):
    sentences = [text.split() for text in texts]
    glove_model = Word2Vec(
        sentences=sentences,
        vector_size=dim,
        window=window,
        min_count=1,
        sg=0,                # CBOW as in GloVe
        workers=4,
        epochs=epochs
    )
    glove_model.wv.save_word2vec_format(output_file, binary=False)

glove_output_file = os.path.join(output_path, 'glove_embeddings.txt')
create_glove_embeddings(df_copy['Text'], glove_output_file)
# Out:
# 2024-12-20 06:15:49,741 | INFO | gensim.models.word2vec | collecting all words and their counts
# 2024-12-20 06:15:49,744 | INFO | gensim.models.word2vec | PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-12-20 06:15:49,764 | INFO | gensim.models.word2vec | collected 9517 word types from a corpus of 72367 raw words and 4035 sentences
# 2024-12-20 06:15:49,767 | INFO | gensim.models.word2vec | Creating a fresh vocabulary
# 2024-12-20 06:15:49,850 | INFO | gensim.utils | Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 9517 unique words (100.00% of original 9517, drops 0)', 'datetime': '2024-12-20T06:15:49.847600', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-20 06:15:49,851 | INFO | gensim.utils | Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 72367 word corpus (100.00% of original 72367, drops 0)', 'datetime': '2024-12-20T06:15:49.851621', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-20 06:15:49,906 | INFO | gensim.models.word2vec | deleting the raw counts dictionary of 9517 items
# 2024-12-20 06:15:49,939 | INFO | gensim.models.word2vec | sample=0.001 downsamples 41 most-common words
# 2024-12-20 06:15:49,940 | INFO | gensim.utils | Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 57113.86719634944 word corpus (78.9%% of prior 72367)', 'datetime': '2024-12-20T06:15:49.940380', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'prepare_vocab'}
# 2024-12-20 06:15:50,047 | INFO | gensim.models.word2vec | estimated required memory for 9517 words and 100 dimensions: 12372100 bytes
# 2024-12-20 06:15:50,049 | INFO | gensim.models.word2vec | resetting layer weights
# 2024-12-20 06:15:50,273 | INFO | gensim.utils | Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-12-20T06:15:50.273104', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'build_vocab'}
# 2024-12-20 06:15:50,274 | INFO | gensim.utils | Word2Vec lifecycle event {'msg': 'training model with 4 workers on 9517 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-12-20T06:15:50.274969', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'train'}
# 2024-12-20 06:15:50,386 | INFO | gensim.models.word2vec | EPOCH 0: training on 72367 raw words (57152 effective words) took 0.1s, 991958 effective words/s
# 2024-12-20 06:15:50,444 | INFO | gensim.models.word2vec | EPOCH 1: training on 72367 raw words (57030 effective words) took 0.1s, 1128481 effective words/s
# 2024-12-20 06:15:50,502 | INFO | gensim.models.word2vec | EPOCH 2: training on 72367 raw words (57114 effective words) took 0.1s, 1139742 effective words/s
# 2024-12-20 06:15:50,564 | INFO | gensim.models.word2vec | EPOCH 3: training on 72367 raw words (57136 effective words) took 0.1s, 1059492 effective words/s
# 2024-12-20 06:15:50,626 | INFO | gensim.models.word2vec | EPOCH 4: training on 72367 raw words (57034 effective words) took 0.1s, 1068998 effective words/s
# 2024-12-20 06:15:50,680 | INFO | gensim.models.word2vec | EPOCH 5: training on 72367 raw words (57035 effective words) took 0.0s, 1165196 effective words/s
# 2024-12-20 06:15:50,748 | INFO | gensim.models.word2vec | EPOCH 6: training on 72367 raw words (57071 effective words) took 0.1s, 965890 effective words/s
# 2024-12-20 06:15:50,807 | INFO | gensim.models.word2vec | EPOCH 7: training on 72367 raw words (56983 effective words) took 0.1s, 1131311 effective words/s
# 2024-12-20 06:15:50,868 | INFO | gensim.models.word2vec | EPOCH 8: training on 72367 raw words (57111 effective words) took 0.1s, 1047328 effective words/s
# 2024-12-20 06:15:50,925 | INFO | gensim.models.word2vec | EPOCH 9: training on 72367 raw words (57112 effective words) took 0.0s, 1161896 effective words/s
# 2024-12-20 06:15:50,994 | INFO | gensim.models.word2vec | EPOCH 10: training on 72367 raw words (57090 effective words) took 0.1s, 958927 effective words/s
# 2024-12-20 06:15:51,067 | INFO | gensim.models.word2vec | EPOCH 11: training on 72367 raw words (57187 effective words) took 0.1s, 852572 effective words/s
# 2024-12-20 06:15:51,128 | INFO | gensim.models.word2vec | EPOCH 12: training on 72367 raw words (57200 effective words) took 0.1s, 1101003 effective words/s
# 2024-12-20 06:15:51,189 | INFO | gensim.models.word2vec | EPOCH 13: training on 72367 raw words (57214 effective words) took 0.1s, 1085333 effective words/s
# 2024-12-20 06:15:51,246 | INFO | gensim.models.word2vec | EPOCH 14: training on 72367 raw words (57114 effective words) took 0.1s, 1106776 effective words/s
# 2024-12-20 06:15:51,248 | INFO | gensim.utils | Word2Vec lifecycle event {'msg': 'training on 1085505 raw words (856583 effective words) took 1.0s, 881430 effective words/s', 'datetime': '2024-12-20T06:15:51.248101', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'train'}
# 2024-12-20 06:15:51,249 | INFO | gensim.utils | Word2Vec lifecycle event {'params': 'Word2Vec<vocab=9517, vector_size=100, alpha=0.025>', 'datetime': '2024-12-20T06:15:51.249717', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'created'}
# 2024-12-20 06:15:51,257 | INFO | gensim.models.keyedvectors | storing 9517x100 projection weights into ../Data/Preprocessed/glove_embeddings.txt

# %%
# Load GloVe embeddings
embeddings_dict = {}
with open("../Data/Preprocessed/glove_embeddings.txt", 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

for word in list(embeddings_dict.keys())[:10]:  # Check the first 10 words
    vector = embeddings_dict[word]
    print(f"{word}: vector length = {len(vector)}")
# Out:
# 9517: vector length = 1
# को: vector length = 100
# ।: vector length = 100
# लाई: vector length = 100
# ले: vector length = 100
# मा: vector length = 100
# ,: vector length = 100
# यो: vector length = 100
# हरु: vector length = 100
# छ: vector length = 100

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
from matplotlib.widgets import RectangleSelector
import matplotlib

# Set the font to use Lohit Devanagari
matplotlib.rcParams['font.family'] = 'Lohit Devanagari'
matplotlib.rcParams['text.usetex'] = False  # Disable TeX rendering

# Load GloVe embeddings
embeddings_dict = {}
with open("../Data/Preprocessed/glove_embeddings.txt", 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# Prepare t-SNE
tsne = TSNE(n_components=2, random_state=0)

# Sample words for visualization (e.g., top 1000 based on frequency)
words = list(embeddings_dict.keys())
vectors = np.array([embeddings_dict[word] for word in words])  # Convert to 2D array

# Fit t-SNE
Y = tsne.fit_transform(vectors[:1000])  # Reduce the dimensionality of the top 1000 words

# Plot
fig, ax = plt.subplots(figsize=(12, 8))
sc = ax.scatter(Y[:, 0], Y[:, 1])

# Annotate points
for label, x, y in zip(words[:1000], Y[:, 0], Y[:, 1]):
    ax.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points", fontsize=8)

plt.title('GloVe Embeddings Visualization')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')

# Zoom functionality
def on_select(eclick, erelease):
    x0, x1 = sorted([eclick.xdata, erelease.xdata])
    y0, y1 = sorted([eclick.ydata, erelease.ydata])
    
    ax.set_xlim(x0, x1)
    ax.set_ylim(y0, y1)
    
    # Clear previous points and annotations
    ax.clear()
    sc = ax.scatter(Y[:, 0], Y[:, 1])
    
    # Add annotations again
    for label, x, y in zip(words[:1000], Y[:, 0], Y[:, 1]):
        ax.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points", fontsize=8)

    plt.draw()


# RectangleSelector
rect_selector = RectangleSelector(ax, on_select, 
                                   button=[1],  # Left mouse button
                                   interactive=True)

plt.show()
# Out:
# /home/angel-tamang/myenv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from font(s) Lohit Devanagari.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/angel-tamang/myenv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9994 (\N{RAISED FIST}) missing from font(s) Lohit Devanagari.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - We did create .txt file, to use the saved model use keyedVectors methods to import the models for efficiency
# - eg:
# - glove_model = KeyedVectors.load_word2vec_format('../Data/Preprocessed/glove_embeddings.txt', binary=False

# %%
# eg for each model

# Load FastText model
fasttext_model = FastText.load("../Data/Preprocessed/fasttext_embeddings.model")

# Access word vectors
vector = fasttext_model.wv['देश']  
print(vector)
# Out:
# 2024-12-19 20:12:52,346 | INFO | gensim.utils | loading FastText object from ../Data/Preprocessed/fasttext_embeddings.model
# 2024-12-19 20:12:52,370 | INFO | gensim.utils | loading wv recursively from ../Data/Preprocessed/fasttext_embeddings.model.wv.* with mmap=None
# 2024-12-19 20:12:52,371 | INFO | gensim.utils | loading vectors_ngrams from ../Data/Preprocessed/fasttext_embeddings.model.wv.vectors_ngrams.npy with mmap=None
# 2024-12-19 20:12:56,524 | INFO | gensim.utils | setting ignored attribute buckets_word to None
# 2024-12-19 20:12:56,530 | INFO | gensim.utils | setting ignored attribute vectors to None
# 2024-12-19 20:12:56,874 | INFO | gensim.utils | setting ignored attribute cum_table to None
# 2024-12-19 20:12:56,952 | INFO | gensim.utils | FastText lifecycle event {'fname': '../Data/Preprocessed/fasttext_embeddings.model', 'datetime': '2024-12-19T20:12:56.952139', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'loaded'}
# [-3.5821024e-01 -4.1248593e-01 -1.0008446e+00 -1.0355966e+00
#   3.6521387e-01  2.0313678e+00 -1.6066047e+00  1.4324358e-01
#   4.0892866e-02 -7.1184045e-01 -9.8550171e-01 -5.0196320e-01
#   6.1680740e-01  3.8002858e-01  1.0447874e+00 -5.9176415e-01
#   3.0078664e-01 -4.6508870e-01  4.4479176e-01 -2.1627829e+00
#  -9.7937298e-01 -1.1508491e+00 -1.5497589e-01 -4.5007128e-01
#   8.6731287e-03  8.3448291e-02 -4.1643840e-01 -6.5672331e-02
#   2.7998179e-01 -2.4297979e-01  8.4169912e-01  8.7035757e-01
#  -4.3221286e-01 -1.1134650e+00 -4.4310647e-01 -9.1839439e-01
#  -4.9482819e-01 -1.3603675e-01  1.1628174e+00 -2.3779538e-01
#  -5.7213753e-01 -4.8705450e-01 -2.2629842e-01  2.2322211e+00
#   1.9116957e-01 -6.2684470e-04 -7.2979969e-01 -6.5999269e-01
#   5.9008658e-01  7.1787828e-01 -1.7865512e-01  3.2883164e-02
#   5.9989083e-01  2.7266231e-01 -4.3556830e-01  6.8903172e-01
#  -6.7680210e-01  4.2247844e-01  1.4052341e+00 -2.6425699e-02
#  -1.2681935e+00  9.2556316e-01  9.0084904e-01  6.4830762e-01
#  -3.4750217e-01  6.6636801e-01 -6.4664567e-01  1.5879630e+00
#  -1.0806884e+00 -2.6462248e-01  7.6444912e-01  1.3610008e+00
#   3.3387068e-01  8.9800894e-02  8.0035603e-01  1.2328643e+00
#  -1.0528624e+00 -4.8668242e-01  3.1071601e-02  6.6967690e-01
#   3.1277806e-01 -6.1021324e-02 -2.6279101e-01 -1.9075139e-01
#  -9.5999348e-01  3.2747468e-01 -5.5930322e-01  5.5208319e-01
#  -2.8334779e-01 -2.1002528e-01 -9.5164597e-01 -2.5217313e-01
#   3.3506346e-01  3.1795818e-01  2.3490551e+00  8.8650388e-01
#   4.4215468e-01 -7.6846069e-01  1.0780866e+00 -1.1588891e+00]

# %%
# Load the Word2Vec model
word2vec_model = Word2Vec.load("../Data/Preprocessed/word2vec_embeddings.txt")

sample_word = 'को'  
vector = word2vec_model.wv[sample_word]

print(f"Vector for {sample_word}: {vector}")
# Out:
# 2024-12-19 20:19:13,346 | INFO | gensim.utils | loading Word2Vec object from ../Data/Preprocessed/word2vec_embeddings.txt
# 2024-12-19 20:19:13,415 | INFO | gensim.utils | loading wv recursively from ../Data/Preprocessed/word2vec_embeddings.txt.wv.* with mmap=None
# 2024-12-19 20:19:13,416 | INFO | gensim.utils | setting ignored attribute cum_table to None
# 2024-12-19 20:19:13,490 | INFO | gensim.utils | Word2Vec lifecycle event {'fname': '../Data/Preprocessed/word2vec_embeddings.txt', 'datetime': '2024-12-19T20:19:13.490746', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'loaded'}
# Vector for को: [-6.10913217e-01  8.94695222e-01  9.16843593e-01  7.21895278e-01
#  -1.60915218e-02 -1.30920875e+00  4.38319921e-01  2.59713793e+00
#  -1.39490247e+00 -1.11303031e+00 -3.92438650e-01 -1.60793173e+00
#   1.81878477e-01  6.62396073e-01  2.68260986e-01 -1.42263126e+00
#   6.25417590e-01 -9.80028450e-01  8.97926018e-02 -2.30519462e+00
#   8.05808067e-01  2.75762498e-01  1.44905722e+00  2.04980090e-01
#  -3.05192530e-01  6.93400577e-02 -5.80408692e-01  1.11256175e-01
#  -1.32532012e+00 -2.72607327e-01  6.46622956e-01 -5.19186519e-02
#  -2.24594749e-03 -1.65126932e+00 -3.71511996e-01  1.09894598e+00
#   2.23491862e-02 -1.02064836e+00 -1.05362332e+00 -1.50095463e+00
#  -5.62444985e-01 -7.63408184e-01 -2.13382825e-01  2.00557977e-01
#   5.23591876e-01 -5.37080646e-01 -9.60749328e-01 -1.49821401e-01
#   5.87704480e-01  5.70565164e-01  3.90501708e-01 -8.10508668e-01
#   5.83019257e-02 -6.00480855e-01 -1.10811986e-01  2.61542946e-01
#   9.73380148e-01 -6.01314865e-02 -1.23693860e+00  6.83172464e-01
#   1.99834317e-01  5.52172661e-01 -1.64553627e-01  4.36014503e-01
#  -1.68343890e+00  1.18738413e+00  5.21768570e-01  1.84953022e+00
#  -1.31940293e+00  8.94144535e-01  5.38449526e-01  1.70535302e+00
#   1.99776256e+00 -7.46610016e-02  9.97310519e-01  4.39998865e-01
#   2.69706786e-01 -6.97144270e-01 -9.64202821e-01 -8.00449789e-01
#  -1.22773719e+00 -3.76034915e-01 -1.27370560e+00  9.56409693e-01
#  -7.12696195e-01 -1.39125669e+00  7.98488021e-01  1.02874303e+00
#   1.34291244e+00  1.56354457e-01  1.69037282e+00 -4.33661371e-01
#   6.09299898e-01  1.98569328e-01  2.72603321e+00  5.89779854e-01
#   9.45937634e-01 -6.75485432e-01  5.22849441e-01 -1.46142438e-01]

# %%
# Load GloVe model
glove_model = KeyedVectors.load_word2vec_format("../Data/Preprocessed/glove_embeddings.txt", binary=False)

# Access word vectors
vector = glove_model['देश']
print(vector)
# Out:
# 2024-12-20 06:24:17,597 | INFO | gensim.models.keyedvectors | loading projection weights from ../Data/Preprocessed/glove_embeddings.txt
# 2024-12-20 06:24:18,290 | INFO | gensim.utils | KeyedVectors lifecycle event {'msg': 'loaded (9517, 100) matrix of type float32 from ../Data/Preprocessed/glove_embeddings.txt', 'binary': False, 'encoding': 'utf8', 'datetime': '2024-12-20T06:24:18.290265', 'gensim': '4.3.3', 'python': '3.11.4 (main, Dec  7 2023, 15:43:41) [GCC 12.3.0]', 'platform': 'Linux-6.2.0-39-generic-x86_64-with-glibc2.37', 'event': 'load_word2vec_format'}
# [-0.48766991  0.9723677   0.8148408   0.13571821 -0.0417061  -0.27670676
#   0.20385697  1.8411604   0.03486707 -0.5157216  -0.28037834 -0.88197523
#   0.04745149  0.15732025 -0.63585633 -1.2556411   0.24903165 -0.57143056
#   0.2891682  -1.3405461   0.43809885  0.4498337   0.5898006   0.23466155
#  -0.6570527   0.09988759  0.6656425   0.30757132 -0.8546909  -0.5629674
#   0.33986384 -0.77456397 -0.156657   -1.1198577  -0.35245883 -0.33446792
#   1.0065074  -0.46216252 -0.48291594  0.2685942  -0.1489789  -0.26068914
#  -0.80131656  0.51764435  0.4025018  -0.28843343 -0.57114345 -0.38813093
#   0.10144154  0.23264308 -0.13199742 -0.6580606   0.17421566 -0.5374994
#   0.10770434  0.1335009   0.29612932 -0.19267777 -0.31699896  0.4927755
#   0.14568661 -0.08640034 -0.11150903  0.1172484  -0.62029904  0.47436476
#   0.01764338  1.2341148  -0.72161084  0.68015337  0.3310983   1.3059474
#   1.1451708  -0.2314215   0.4844971  -0.10855011  0.9208265  -0.44874257
#  -0.51026356 -0.510203   -1.1568898  -0.55089766 -0.9836126   0.09914831
#  -0.5155616  -1.4927801   0.3456684   0.5245335   0.7398194  -0.23531748
#   1.2593418   0.23596013  0.523178    0.6770095   1.6164407   0.28916842
#   1.3696911  -0.098162   -0.22358102 -0.10847874]

# %%
words= df["Text"].loc[0].split()

# %%
word_vectors=[glove_model[words]]
print(word_vectors)
# Out:
# [array([[-0.2505824 ,  0.18538585,  0.3547338 , ..., -0.2772198 ,
#          0.01105034, -0.10770611],
#        [-0.09928526,  0.09167412,  0.11909453, ..., -0.10668852,
#          0.02735105, -0.00528737],
#        [-0.22634785,  0.33923748,  0.3293186 , ..., -0.21763001,
#          0.06568737,  0.01443712],
#        ...,
#        [-0.01388085,  0.03777543,  0.03188535, ..., -0.02150066,
#          0.00521871,  0.00418475],
#        [-0.09928526,  0.09167412,  0.11909453, ..., -0.10668852,
#          0.02735105, -0.00528737],
#        [-0.17676644,  0.5874823 ,  0.5746554 , ..., -0.6979505 ,
#          0.34504437, -0.03337139]], dtype=float32)]

# %% [markdown]
# ## load the models in similar fashion while model training
